# %% [markdown]
# Analysing Tabular Data Using Python and Pandas ********************************************

# %%
import pandas as pd

# %%
covid_df=pd.read_csv('italy-covid-daywise.csv')

# %%
type(covid_df)
# Out:
# pandas.core.frame.DataFrame

# %%
covid_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        248 non-null    object
#  1   new_cases   248 non-null    float64
#  2   new_deaths  248 non-null    float64
#  3   new_tests   135 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 7.9+ KB

# %%
covid_df.describe()
# Out:
#          new_cases  new_deaths     new_tests
# count   248.000000  248.000000    135.000000
# mean   1094.818548  143.133065  31699.674074
# std    1554.508002  227.105538  11622.209757
# min    -148.000000  -31.000000   7841.000000
# 25%     123.000000    3.000000  25259.000000
# 50%     342.000000   17.000000  29545.000000
# 75%    1371.750000  175.250000  37711.000000
# max    6557.000000  971.000000  95273.000000

# %%
covid_df.shape
# Out:
# (248, 4)

# %% [markdown]
# Analysing data from data frame *********************

# %%
#number of reported cases and deaths
total_cases=covid_df.new_cases.sum()
total_deaths=covid_df.new_deaths.sum()

# %%
print('the number of repoted cases is {} and the number of reported deaths is {}:'.format(total_cases,total_deaths))
# Out:
# the number of repoted cases is 271515.0 and the number of reported deaths is 35497.0:

# %%
#overall deaths rate
death_rate=total_deaths/total_cases

# %%
print('the deaths rate is {:.2f} %.'.format(death_rate*100))
# Out:
# the deaths rate is 13.07 %.

# %% [markdown]
# Querying and sorting row *******************

# %%
high_new_cases=covid_df.new_cases > 1000

# %%
high_new_cases
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 243     True
# 244     True
# 245    False
# 246    False
# 247     True
# Name: new_cases, Length: 248, dtype: bool

# %%
covid_df[high_new_cases]
# Out:
#            date  new_cases  new_deaths  new_tests
# 68   2020-03-08     1247.0        36.0        NaN
# 69   2020-03-09     1492.0       133.0        NaN
# 70   2020-03-10     1797.0        98.0        NaN
# 72   2020-03-12     2313.0       196.0        NaN
# 73   2020-03-13     2651.0       189.0        NaN
# ..          ...        ...         ...        ...
# 241  2020-08-28     1409.0         5.0    65135.0
# 242  2020-08-29     1460.0         9.0    64294.0
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 247  2020-09-03     1326.0         6.0        NaN
#
# [72 rows x 4 columns]

# %%
from IPython.display import display
with pd.option_context('display.max_rows',100):
    display(covid_df[covid_df.new_cases > 1000])
# Out:
#            date  new_cases  new_deaths  new_tests
# 68   2020-03-08     1247.0        36.0        NaN
# 69   2020-03-09     1492.0       133.0        NaN
# 70   2020-03-10     1797.0        98.0        NaN
# 72   2020-03-12     2313.0       196.0        NaN
# 73   2020-03-13     2651.0       189.0        NaN
# 74   2020-03-14     2547.0       252.0        NaN
# 75   2020-03-15     3497.0       173.0        NaN
# 76   2020-03-16     2823.0       370.0        NaN
# 77   2020-03-17     4000.0       347.0        NaN
# 78   2020-03-18     3526.0       347.0        NaN
# 79   2020-03-19     4207.0       473.0        NaN
# 80   2020-03-20     5322.0       429.0        NaN
# 81   2020-03-21     5986.0       625.0        NaN
# 82   2020-03-22     6557.0       795.0        NaN
# 83   2020-03-23     5560.0       649.0        NaN
# 84   2020-03-24     4789.0       601.0        NaN
# 85   2020-03-25     5249.0       743.0        NaN
# 86   2020-03-26     5210.0       685.0        NaN
# ...

# %%
# !pip install jovian

# %%
import jovian

# %%
jovian.commit(filename='Python_Lesson4.ipynb')
# Out:
# [jovian] Please enter your API key ( from https://jovian.com/ ):
# API KEY:
#   ········
# [jovian] Committed successfully! https://jovian.com/odiouf812/python-lesson4
# 'https://jovian.com/odiouf812/python-lesson4'

# %%
import pandas as pd

# %%
covid_df=pd.read_csv('italy-covid-daywise.csv')

# %%
initial_tests=935310
total_tests=initial_tests + covid_df.new_tests.sum()

# %%
total_tests
# Out:
# 5214766.0

# %%
positive_rates=total_tests/total_tests

# %%
print('{:.2f} % of tests in Italy led to a positive diagnosis.'.format(positive_rates*100))
# Out:
# 100.00 % of tests in Italy led to a positive diagnosis.

# %%
import jovian

# %%
jovian.commit(filename='Python_Lesson4.ipynb')
# Out:
# [jovian] Updating notebook "odiouf812/python-lesson4" on https://jovian.com/
# [jovian] Committed successfully! https://jovian.com/odiouf812/python-lesson4
# 'https://jovian.com/odiouf812/python-lesson4'

# %% [markdown]
# Querying and sorting rows******************************

# %%
high_new_cases=covid_df.new_cases > 1000

# %%
high_new_cases
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 243     True
# 244     True
# 245    False
# 246    False
# 247     True
# Name: new_cases, Length: 248, dtype: bool

# %%
covid_df[high_new_cases]
# Out:
#            date  new_cases  new_deaths  new_tests
# 68   2020-03-08     1247.0        36.0        NaN
# 69   2020-03-09     1492.0       133.0        NaN
# 70   2020-03-10     1797.0        98.0        NaN
# 72   2020-03-12     2313.0       196.0        NaN
# 73   2020-03-13     2651.0       189.0        NaN
# ..          ...        ...         ...        ...
# 241  2020-08-28     1409.0         5.0    65135.0
# 242  2020-08-29     1460.0         9.0    64294.0
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 247  2020-09-03     1326.0         6.0        NaN
#
# [72 rows x 4 columns]

# %%
high_cases_df=covid_df[covid_df.new_cases > 1000]

# %%
high_cases_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 68   2020-03-08     1247.0        36.0        NaN
# 69   2020-03-09     1492.0       133.0        NaN
# 70   2020-03-10     1797.0        98.0        NaN
# 72   2020-03-12     2313.0       196.0        NaN
# 73   2020-03-13     2651.0       189.0        NaN
# ..          ...        ...         ...        ...
# 241  2020-08-28     1409.0         5.0    65135.0
# 242  2020-08-29     1460.0         9.0    64294.0
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 247  2020-09-03     1326.0         6.0        NaN
#
# [72 rows x 4 columns]

# %%
positive_rates
# Out:
# 1.0

# %%
high_ratio_df=covid_df[covid_df.new_cases/covid_df.new_tests > positive_rates]

# %%
high_ratio_df
# Out:
# Empty DataFrame
# Columns: [date, new_cases, new_deaths, new_tests]
# Index: []

# %% [markdown]
# adding a new column ************************

# %%
covid_df['positive_rates']=covid_df.new_cases/covid_df.new_tests

# %%
covid_df
# Out:
#            date  new_cases  new_deaths  new_tests  positive_rates
# 0    2019-12-31        0.0         0.0        NaN             NaN
# 1    2020-01-01        0.0         0.0        NaN             NaN
# 2    2020-01-02        0.0         0.0        NaN             NaN
# 3    2020-01-03        0.0         0.0        NaN             NaN
# 4    2020-01-04        0.0         0.0        NaN             NaN
# ..          ...        ...         ...        ...             ...
# 243  2020-08-30     1444.0         1.0    53541.0        0.026970
# 244  2020-08-31     1365.0         4.0    42583.0        0.032055
# 245  2020-09-01      996.0         6.0    54395.0        0.018311
# 246  2020-09-02      975.0         8.0        NaN             NaN
# 247  2020-09-03     1326.0         6.0        NaN             NaN
#
# [248 rows x 5 columns]

# %% [markdown]
# remove a column ***********************

# %%
covid_df.drop(columns=['positive_rates'], inplace=True)

# %%
covid_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %% [markdown]
# sorting rows using columns values **********************************

# %%
covid_df.sort_values('new_cases', ascending=False).head(20)
# Out:
#            date  new_cases  new_deaths  new_tests
# 82   2020-03-22     6557.0       795.0        NaN
# 87   2020-03-27     6153.0       660.0        NaN
# 81   2020-03-21     5986.0       625.0        NaN
# 89   2020-03-29     5974.0       887.0        NaN
# 88   2020-03-28     5959.0       971.0        NaN
# 83   2020-03-23     5560.0       649.0        NaN
# 80   2020-03-20     5322.0       429.0        NaN
# 85   2020-03-25     5249.0       743.0        NaN
# 90   2020-03-30     5217.0       758.0        NaN
# 86   2020-03-26     5210.0       685.0        NaN
# 96   2020-04-05     4805.0       681.0        NaN
# 84   2020-03-24     4789.0       601.0        NaN
# 93   2020-04-02     4782.0       727.0        NaN
# 103  2020-04-12     4694.0       619.0        NaN
# 94   2020-04-03     4668.0       760.0        NaN
# 95   2020-04-04     4585.0       764.0        NaN
# 97   2020-04-06     4316.0       527.0        NaN
# 79   2020-03-19     4207.0       473.0        NaN
# ...

# %%
covid_df.sort_values('new_deaths', ascending=False).head(10)
# Out:
#           date  new_cases  new_deaths  new_tests
# 88  2020-03-28     5959.0       971.0        NaN
# 89  2020-03-29     5974.0       887.0        NaN
# 92  2020-04-01     4053.0       839.0        NaN
# 91  2020-03-31     4050.0       810.0        NaN
# 82  2020-03-22     6557.0       795.0        NaN
# 95  2020-04-04     4585.0       764.0        NaN
# 94  2020-04-03     4668.0       760.0        NaN
# 90  2020-03-30     5217.0       758.0        NaN
# 85  2020-03-25     5249.0       743.0        NaN
# 93  2020-04-02     4782.0       727.0        NaN

# %%
covid_df.loc[169:175]
# Out:
#            date  new_cases  new_deaths  new_tests
# 169  2020-06-17      210.0        34.0    33957.0
# 170  2020-06-18      328.0        43.0    32921.0
# 171  2020-06-19      331.0        66.0    28570.0
# 172  2020-06-20     -148.0        47.0    29875.0
# 173  2020-06-21      264.0        49.0    24581.0
# 174  2020-06-22      224.0        24.0    16152.0
# 175  2020-06-23      221.0        23.0    23225.0

# %%
import jovian

# %%
jovian.commit(filename='Python_Lesson4.ipynb')
# Out:
# [jovian] Please enter your API key ( from https://jovian.com/ ):
# API KEY:
#   ········
# [jovian] Committed successfully! https://jovian.com/odiouf812/python-lesson4
# 'https://jovian.com/odiouf812/python-lesson4'

# %% [markdown]
# working with dates *************************************

# %%
covid_df.date
# Out:
# 0      2019-12-31
# 1      2020-01-01
# 2      2020-01-02
# 3      2020-01-03
# 4      2020-01-04
#           ...
# 243    2020-08-30
# 244    2020-08-31
# 245    2020-09-01
# 246    2020-09-02
# 247    2020-09-03
# Name: date, Length: 248, dtype: object

# %% [markdown]
# convert into a date time ****************************************

# %%
covid_df['date']=pd.to_datetime(covid_df.date)

# %%
covid_df['date']
# Out:
# 0     2019-12-31
# 1     2020-01-01
# 2     2020-01-02
# 3     2020-01-03
# 4     2020-01-04
#          ...
# 243   2020-08-30
# 244   2020-08-31
# 245   2020-09-01
# 246   2020-09-02
# 247   2020-09-03
# Name: date, Length: 248, dtype: datetime64[ns]

# %% [markdown]
# Extracting different parts of the data into separate columns ************************************************

# %%
covid_df['year']=pd.DatetimeIndex(covid_df.date).year

# %%
covid_df
# Out:
#           date  new_cases  new_deaths  new_tests  year
# 0   2019-12-31        0.0         0.0        NaN  2019
# 1   2020-01-01        0.0         0.0        NaN  2020
# 2   2020-01-02        0.0         0.0        NaN  2020
# 3   2020-01-03        0.0         0.0        NaN  2020
# 4   2020-01-04        0.0         0.0        NaN  2020
# ..         ...        ...         ...        ...   ...
# 243 2020-08-30     1444.0         1.0    53541.0  2020
# 244 2020-08-31     1365.0         4.0    42583.0  2020
# 245 2020-09-01      996.0         6.0    54395.0  2020
# 246 2020-09-02      975.0         8.0        NaN  2020
# 247 2020-09-03     1326.0         6.0        NaN  2020
#
# [248 rows x 5 columns]

# %% [markdown]
# Overall metrics of may ********************************************************

# %%
#query the rows for 2019
covid_df_2019=covid_df[covid_df.year==2019]

# %%
#query the rows for 2020
covid_df_2020=covid_df[covid_df.year==2020]

# %%
covid_df_2020
# Out:
#           date  new_cases  new_deaths  new_tests  year
# 1   2020-01-01        0.0         0.0        NaN  2020
# 2   2020-01-02        0.0         0.0        NaN  2020
# 3   2020-01-03        0.0         0.0        NaN  2020
# 4   2020-01-04        0.0         0.0        NaN  2020
# 5   2020-01-05        0.0         0.0        NaN  2020
# ..         ...        ...         ...        ...   ...
# 243 2020-08-30     1444.0         1.0    53541.0  2020
# 244 2020-08-31     1365.0         4.0    42583.0  2020
# 245 2020-09-01      996.0         6.0    54395.0  2020
# 246 2020-09-02      975.0         8.0        NaN  2020
# 247 2020-09-03     1326.0         6.0        NaN  2020
#
# [247 rows x 5 columns]

# %%
#Extract a subset of columns
covid_df_2020_metrics=covid_df[['new_cases', 'new_deaths', 'new_tests']]

# %%
covid_df_2020_metrics
# Out:
#      new_cases  new_deaths  new_tests
# 0          0.0         0.0        NaN
# 1          0.0         0.0        NaN
# 2          0.0         0.0        NaN
# 3          0.0         0.0        NaN
# 4          0.0         0.0        NaN
# ..         ...         ...        ...
# 243     1444.0         1.0    53541.0
# 244     1365.0         4.0    42583.0
# 245      996.0         6.0    54395.0
# 246      975.0         8.0        NaN
# 247     1326.0         6.0        NaN
#
# [248 rows x 3 columns]

# %%
#get the columns wise sum
covid_2020_total=covid_df_2020_metrics.sum()

# %%
covid_2020_total
# Out:
# new_cases      271515.0
# new_deaths      35497.0
# new_tests     4279456.0
# dtype: float64

# %%
import jovian

# %%
jovian.commit(filename='Python_Lesson4.ipynb')
# Out:
# [jovian] Updating notebook "odiouf812/python-lesson4" on https://jovian.com/
# [jovian] Committed successfully! https://jovian.com/odiouf812/python-lesson4
# 'https://jovian.com/odiouf812/python-lesson4'

# %% [markdown]
# ************Grouping and aggregation *********************************************

# %%
covid_year_df=covid_df.groupby('year')[['new_cases', 'new_deaths', 'new_tests']].sum()

# %%
covid_year_means_df=covid_df.groupby('year')[['new_cases', 'new_deaths', 'new_tests']].mean()

# %%
covid_year_means_df
# Out:
#         new_cases  new_deaths     new_tests
# year
# 2019     0.000000    0.000000           NaN
# 2020  1099.251012  143.712551  31699.674074

# %%
# Merging data from multiple sources
locations_df=pd.read_csv('locations.csv')

# %%
locations_df
# Out:
#           location continent    population  life_expectancy  \
# 0      Afghanistan      Asia  3.892834e+07            64.83
# 1          Albania    Europe  2.877800e+06            78.57
# 2          Algeria    Africa  4.385104e+07            76.88
# 3          Andorra    Europe  7.726500e+04            83.73
# 4           Angola    Africa  3.286627e+07            61.15
# ..             ...       ...           ...              ...
# 207          Yemen      Asia  2.982597e+07            66.12
# 208         Zambia    Africa  1.838396e+07            63.89
# 209       Zimbabwe    Africa  1.486293e+07            61.49
# 210          World       NaN  7.794799e+09            72.58
# 211  International       NaN           NaN              NaN
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                         0.500        1803.987
# 1                         2.890       11803.431
# 2                         1.900       13913.839
# 3                           NaN             NaN
# ...

# %%
locations_df[locations_df.location=="Italy"]
# Out:
#    location continent  population  life_expectancy  \
# 97    Italy    Europe  60461828.0            83.51
#
#     hospital_beds_per_thousand  gdp_per_capita
# 97                        3.18       35220.084

# %%
covid_df['location']="Italy"

# %%
covid_df
# Out:
#           date  new_cases  new_deaths  new_tests  year location
# 0   2019-12-31        0.0         0.0        NaN  2019    Italy
# 1   2020-01-01        0.0         0.0        NaN  2020    Italy
# 2   2020-01-02        0.0         0.0        NaN  2020    Italy
# 3   2020-01-03        0.0         0.0        NaN  2020    Italy
# 4   2020-01-04        0.0         0.0        NaN  2020    Italy
# ..         ...        ...         ...        ...   ...      ...
# 243 2020-08-30     1444.0         1.0    53541.0  2020    Italy
# 244 2020-08-31     1365.0         4.0    42583.0  2020    Italy
# 245 2020-09-01      996.0         6.0    54395.0  2020    Italy
# 246 2020-09-02      975.0         8.0        NaN  2020    Italy
# 247 2020-09-03     1326.0         6.0        NaN  2020    Italy
#
# [248 rows x 6 columns]

# %%
merged_df=covid_df.merge(locations_df, on="location")

# %%
merged_df
# Out:
#           date  new_cases  new_deaths  new_tests  year location continent  \
# 0   2019-12-31        0.0         0.0        NaN  2019    Italy    Europe
# 1   2020-01-01        0.0         0.0        NaN  2020    Italy    Europe
# 2   2020-01-02        0.0         0.0        NaN  2020    Italy    Europe
# 3   2020-01-03        0.0         0.0        NaN  2020    Italy    Europe
# 4   2020-01-04        0.0         0.0        NaN  2020    Italy    Europe
# ..         ...        ...         ...        ...   ...      ...       ...
# 243 2020-08-30     1444.0         1.0    53541.0  2020    Italy    Europe
# 244 2020-08-31     1365.0         4.0    42583.0  2020    Italy    Europe
# 245 2020-09-01      996.0         6.0    54395.0  2020    Italy    Europe
# 246 2020-09-02      975.0         8.0        NaN  2020    Italy    Europe
# 247 2020-09-03     1326.0         6.0        NaN  2020    Italy    Europe
#
#      population  life_expectancy  hospital_beds_per_thousand  gdp_per_capita
# ...

# %%
merged_df['deaths_per_million']=merged_df.new_deaths*1e6/merged_df.population

# %%
merged_df
# Out:
#           date  new_cases  new_deaths  new_tests  year location continent  \
# 0   2019-12-31        0.0         0.0        NaN  2019    Italy    Europe
# 1   2020-01-01        0.0         0.0        NaN  2020    Italy    Europe
# 2   2020-01-02        0.0         0.0        NaN  2020    Italy    Europe
# 3   2020-01-03        0.0         0.0        NaN  2020    Italy    Europe
# 4   2020-01-04        0.0         0.0        NaN  2020    Italy    Europe
# ..         ...        ...         ...        ...   ...      ...       ...
# 243 2020-08-30     1444.0         1.0    53541.0  2020    Italy    Europe
# 244 2020-08-31     1365.0         4.0    42583.0  2020    Italy    Europe
# 245 2020-09-01      996.0         6.0    54395.0  2020    Italy    Europe
# 246 2020-09-02      975.0         8.0        NaN  2020    Italy    Europe
# 247 2020-09-03     1326.0         6.0        NaN  2020    Italy    Europe
#
#      population  life_expectancy  hospital_beds_per_thousand  gdp_per_capita  \
# ...

# %% [markdown]
# ************************Writing data back to file ****************************************************

# %%
result_df=merged_df[['date', 'new_deaths', 'deaths_per_million']]

# %%
result_df
# Out:
#           date  new_deaths  deaths_per_million
# 0   2019-12-31         0.0            0.000000
# 1   2020-01-01         0.0            0.000000
# 2   2020-01-02         0.0            0.000000
# 3   2020-01-03         0.0            0.000000
# 4   2020-01-04         0.0            0.000000
# ..         ...         ...                 ...
# 243 2020-08-30         1.0            0.016539
# 244 2020-08-31         4.0            0.066157
# 245 2020-09-01         6.0            0.099236
# 246 2020-09-02         8.0            0.132315
# 247 2020-09-03         6.0            0.099236
#
# [248 rows x 3 columns]

# %%
result_df.to_csv('result_df.csv', index=None)

# %%
import jovian

# %%
jovian.commit(filename=Python
